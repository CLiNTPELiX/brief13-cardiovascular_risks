# %% [markdown]
# To-Do
#
#
# **En vous appuyant sur ces données, Construisez un modèle de Random Forest permettant de prédire qui sont les sujets à risque !**
#
# * 1. Réaliser une veille sur les Random Forest.
#
# * 2. Utiliser un jupyter-notebook pour le travail qui suit.
#
# * 3. Visualiser et analyser les données avec les librairies Matplotlib et Seaborn.
#
# * 4. Résoudre le cas d’étude présenté ci-dessus avec la librairie Scikit-Learn (exploration des données, préparation des données, modélisation, le test et l’interprétation des résultats).
#
# * 5. **Prédire si Arthur 53 ans, fumeur, sportif, 175 cm, 85 kg, avec un taux de cholestérol au dessus de la normal et un taux de glucose normal, une tension artérielle systolique dans la moyenne et une pression sanguine diastolique correspondant à la moyenne du 3e quartile (50%-75%) du jeu de données, est un sujet à risques cardio-vasculaires.**
#
# * Rendre accessible votre notebook via Github.
#
# * Partager votre lien github.

# %% [markdown]
# #### 1. Réaliser une veille sur les Random Forest

# %% [markdown]
# Random Forest
# Lien :
#
# https://blog.ysance.com/algorithme-n2-comprendre-comment-fonctionne-un-random-forest-en-5-min#:~:text=Le%20random%20forest%20est%20un,assemblage%20d%27arbres%20de%20d%C3%A9cision
#
#
# https://dataanalyticspost.com/Lexique/random-forest/
#
#
# https://www.kongakura.fr/article/Random-Forest-explication-et-impl%C3%A9mentation-avec-sklearn%20python-machine%20learning-
#
# https://datascientest.com/random-forest-definition
#
#
#
# https://fr.wikipedia.org/wiki/For%C3%AAt_d%27arbres_d%C3%A9cisionnels
#
#
#
# Introduction
#
# Arbre de décision :
#
# C'est une méthode d’apprentissage supervisé qui permet de représenter un ensemble de choix sous la forme graphique d’un arbre. Un arbre de décision modélise une hiérarchie de tests pour prédire un résultat. Il existe deux principaux types d’arbre de décision :
# Les arbres de régression (Regression Tree) permettent de prédire une quantité réelle, une valeur numérique .
# Les arbres de classification (Classification Tree) permettent de prédire à quelle classe la variable de sortie appartient.
# Les décisions possibles sont situées à l'extrémité des branches et sont atteintes en fonction de décisions prises à chaque étape.
# Un arbre de décision fonctionne en appliquant de manière itérative des règles logiques très simples, chaque règle étant choisie en fonction du résultat de la règle précédente.
# Ces algorithmes permettent aussi d’extraire des règles logiques qui n’apparaissaient pas dans les données brutes.
# Random Forest :  C'est quoi un arbre de décision ?
#
# Permet de résoudre  un problème en le modélisant comme une suite de décisions en fonction des décisions qui ont été prises ultérieurement.
#
# Peu d’hyper-paramètres à gérer
# De plutôt bonnes performances
# Peu gourmand en données d'apprentissage
# Keep calm and just put the data inside  ===> il faudrait s'assurer  des données belles et bien représentatives de votre problème.
# l'idée derrière le Random Forest est qu'en entraînant plusieurs arbres de décision plutôt qu'un seul, ayant tous une expérience différente le groupe d'arbres de décision sera bien plus à même de prendre une meilleure décision pour résoudre le problème que si ce n'était qu'un seul arbre de décision qui avait été entraîné.
# Comment Random Forest construit ses arbres de décision ?
#   L'algorithme d'entraînement du Random Forest construit chacun des arbres de décisions qui le composent, en les entraînant tous avec un sous-ensemble des données du problème.
#
# N.B:
# Seul bémol, le random forest est une boîte noire qui donne des résultats peu lisibles, c’est-à-dire peu explicatifs.
# Le défaut majeur de l'arbre de décision est que sa performance est fortement dépendante de l'échantillon de données de départ. Par exemple, l'ajout de quelques nouvelles données dans la base d'apprentissage peut modifier radicalement le modèle et les résultats.
#
#
# Documentations :
#
# tree bagging : un tirage aléatoire avec remplacement sur les observations (les lignes de votre base de données)
#
# feature sampling : un tirage aléatoire sur les variables (les colonnes de votre base de données)
#
#
# Random forest = tree bagging + feature sampling.
# le feature sampling permet de réduire la variance
#
# La sagesse de la foule (wisdom of the crowd)
# l'opinion collective d'un groupe d'individus plutôt que celle d'un seul expert.
# Foule grande compétente et diversifiée (Critères importants de taille, compétence et diversité)
# Bagging
# Le mot Bagging est une contraction de Bootstrap Aggregation. Le bagging est une technique utilisée pour améliorer la classification notamment celle des arbres de décision, considérés comme des « classifieurs faibles », c’est-à-dire à peine plus efficaces qu’une classification aléatoire.
#
# Les Random Forest peuvent être composées de plusieurs dizaines voire centaines d’arbres, le nombre d’arbres est un paramètre que l’on ajuste généralement par validation croisée (ou cross-validation en anglais). Pour faire court, la validation croisée est une technique d’évaluation d’un algorithme de Machine Learning consistant à entraîner	 et tester le modèle sur des morceaux du dataset de départ.
#
# Chaque arbre est entraîné sur un sous-ensemble du dataset et donne un résultat (oui ou non dans le cas de notre exemple sur les champignons). Les résultats de tous les arbres de décision sont alors combinés pour donner une réponse finale. Chaque arbre “vote” (oui ou non) et la réponse finale est celle qui a eu la majorité de vote.
#
# La méthode de bagging :
# On découpe notre dataset en plusieurs sous-ensembles aléatoirement constitués d'échantillons d'où le “Random” dans Random Forest.
# On entraîne un modèle sur chaque sous-ensemble : il y a autant de modèles que de sous-ensembles.
# On combine tous les résultats des modèles (avec un système de vote par exemple) ce qui nous donne un résultat final.
# De cette manière on construit un modèle robuste à partir de plusieurs modèles qui ne sont pas forcément aussi robustes.
#
#
# Boosting
#
# Le principe des méthodes de Bagging, et donc en particulier des forêts aléatoires c’est de faire la moyenne des prévisions de plusieurs modèles indépendants pour réduire la variance et donc l’erreur de prévision. Pour construire ces différents modèles, on sélectionne plusieurs échantillons bootstrap, c'est-à dire des tirages avec remises.
#
# Traitement en série des modèles (à la différence bagging qui entraîne en parallèle) qui permet de réduire le biais et les cas d’under-fitting de ce type de modèle.
#
# Le boosting permet de réduire la variance de la foule (et donc de l’over-fitting)
#
# AdaBoost
# Gradient Boosting
#
# Stacking
#
# Entraîner notre modèle sur les prédictions de la foule
# Au lieu de rassembler les prédictions de chaque modèle, on établit un estimateur qui prédira le résultat final.

# %% [markdown]
# #### 3. Visualiser et analyser les données avec les librairies Matplotlib et Seaborn

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import classification_report, confusion_matrix, plot_confusion_matrix, r2_score
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.exceptions import ConvergenceWarning

file = "cardio_train.csv"
df = pd.read_csv(file, sep=';')

# %%
df.dtypes
# Out:
# id               int64
# age              int64
# gender           int64
# height           int64
# weight         float64
# ap_hi            int64
# ap_lo            int64
# cholesterol      int64
# gluc             int64
# smoke            int64
# alco             int64
# active           int64
# cardio           int64
# dtype: object

# %%
# Empty cell(s)?

df.isna().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
# Null or missing value(s)

df.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
df.size
# Out:
# 910000

# %%
#Stats

df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
df.quantile()
# Out:
# id             50001.5
# age            19703.0
# gender             1.0
# height           165.0
# weight            72.0
# ap_hi            120.0
# ap_lo             80.0
# cholesterol        1.0
# gluc               1.0
# smoke              0.0
# alco               0.0
# active             1.0
# cardio             0.0
# Name: 0.5, dtype: float64

# %%
df['cardio'].value_counts()
# Out:
# 0    35021
# 1    34979
# Name: cardio, dtype: int64

# %% [markdown]
# df.shape

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'gender'}>,
#         <AxesSubplot:title={'center':'height'}>],
#        [<AxesSubplot:title={'center':'weight'}>,
#         <AxesSubplot:title={'center':'ap_hi'}>,
#         <AxesSubplot:title={'center':'ap_lo'}>,
#         <AxesSubplot:title={'center':'cholesterol'}>],
#        [<AxesSubplot:title={'center':'gluc'}>,
#         <AxesSubplot:title={'center':'smoke'}>,
#         <AxesSubplot:title={'center':'alco'}>,
#         <AxesSubplot:title={'center':'active'}>],
#        [<AxesSubplot:title={'center':'cardio'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
df.columns
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
#df['age'] =  df['age'] / 365

# %%
df_cleaned = df.drop('id', axis=1)

# %%
sns.countplot(x='gender', data=df, hue='cardio')
plt.show()

# %%
#df_cleaned['years'] = ( df_cleaned['age'] / 365).round(0)
#df_cleaned["years"] = pd.to_numeric(df_cleaned["years"], downcast='integer') # Convert years to an integer

# %%
#sns.countplot(x='years', hue='cardio', data = df)

# %%
df.corr()
# Out:
#                    id       age    gender    height    weight     ap_hi  \
# id           1.000000  0.003457  0.003502 -0.003038 -0.001830  0.003356
# age          0.003457  1.000000 -0.022811 -0.081515  0.053684  0.020764
# gender       0.003502 -0.022811  1.000000  0.499033  0.155406  0.006005
# height      -0.003038 -0.081515  0.499033  1.000000  0.290968  0.005488
# weight      -0.001830  0.053684  0.155406  0.290968  1.000000  0.030702
# ap_hi        0.003356  0.020764  0.006005  0.005488  0.030702  1.000000
# ap_lo       -0.002529  0.017647  0.015254  0.006150  0.043710  0.016086
# cholesterol  0.006106  0.154424 -0.035821 -0.050226  0.141768  0.023778
# gluc         0.002467  0.098703 -0.020491 -0.018595  0.106857  0.011841
# smoke       -0.003699 -0.047633  0.338135  0.187989  0.067780 -0.000922
# alco         0.001210 -0.029723  0.170966  0.094419  0.067113  0.001408
# active       0.003755 -0.009927  0.005866 -0.006570 -0.016867 -0.000033
# ...

# %%
plt.figure(figsize=(8,8)) 
sns.heatmap(df.corr(), fmt='.0%', annot=True, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
#df_cleaned = df_cleaned.drop('years', axis=1)

# %%
#features = df_cleaned[0:12]
features = ['age','gender','height','weight','ap_hi', 'ap_lo', 'cholesterol','gluc', 'smoke', 'alco','active']
plt.figure(figsize=(8,8))
heat = sns.heatmap(df[features].corr(), vmax=1, square=True, annot=True)

# %%
# Anne Laure Méalier

from pandas_profiling import ProfileReport

ProfileReport(df)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.10.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-02-01 09:58:06.540606&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# #### Features ranking

# %%
liste_variables = list(df_cleaned.columns)

importances = scaled_rf.feature_importances_
indices = np.argsort(importances)
# style du graphique 
plt.style.use('fivethirtyeight')
# %matplotlib inline
plt.figure(1)
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [liste_variables[i] for i in indices])
plt.xlabel('Relative Importance')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-c3412450f1ef> in <module>
#       1 liste_variables = list(df_cleaned.columns)
#       2
# ----> 3 importances = scaled_rf.feature_importances_
#       4 indices = np.argsort(importances)
#       5 # style du graphique
#
# NameError: name 'scaled_rf' is not defined

# %% [markdown]
# * #### We can choose features from df[age] -> df[cholesterol]

# %% [markdown]
# #### Calculations

# %%
Q1 = round(np.percentile(df_cleaned['ap_lo'], 25))
Q2 = round(np.percentile(df_cleaned['ap_lo'], 50))
Q3 = round(np.percentile(df_cleaned['ap_lo'], 75))

print("Quartiles 1/2/3:", Q1, Q2, Q3)
# Out:
# Quartiles 1/2/3: 80 80 90

# %%
#print(rf.predict(X))

# %% [markdown]
# #### 5. Prédire si Arthur 53 ans, fumeur, sportif, 175 cm, 85 kg, avec un taux de cholestérol au dessus de la normal et un taux de glucose normal, une tension artérielle systolique dans la moyenne et une pression sanguine diastolique correspondant à la moyenne du 3e quartile (50%-75%) du jeu de données, est un sujet à risques cardio-vasculaires.

# %% [markdown]
# * ### Non-Scaled datas

# %%
df_cleaned.columns
# Out:
# Index(['age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol',
#        'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
X = df_cleaned.drop(['cardio'], axis=1)
y = df_cleaned.cardio

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

score = cross_val_score(rf, X_train, y_train, cv=10)

# %%
y_pred = rf.predict(X_test)
#plot_confusion_matrix(df, X_test, y_test)
print(confusion_matrix(y_test, y_pred))
# Out:
# [[7600 2921]
#  [3103 7376]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.72      0.72     10521
#            1       0.72      0.70      0.71     10479
#
#     accuracy                           0.71     21000
#    macro avg       0.71      0.71      0.71     21000
# weighted avg       0.71      0.71      0.71     21000

# %%
X_Arthur = [[
    19345, 
    2,
    175,
    85,
    129,
    90,
    2,
    1,
    1,
    0,
    1
]]

print(rf.predict(X_Arthur))
# Out:
# [1]

# %%
rf.predict_proba(X_Arthur) # 0.4 class 0, 0.6 class 1
# Out:
# array([[0.42, 0.58]])

# %% [markdown]
# ### Patient is reported with a probability of cancer 58%. Complementary exams must be done¶

# %% [markdown]
# * ### Scaled datas

# %%
df_cleaned.columns
# Out:
# Index(['age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol',
#        'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
X = df_cleaned.drop(['cardio'], axis=1)
y = df_cleaned.cardio

scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)

# %%
#scaled_X

# %%
#df_cleaned.columns

# %%
X_train_scaled, X_test_scaled, y_train_scaled, y_test_scaled = train_test_split(scaled_X, y, test_size=0.3)

scaled_rf = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=42)
scaled_rf.fit(X_train_scaled, y_train_scaled)

score = cross_val_score(scaled_rf, X_train_scaled, y_train_scaled, cv=10)

# %%
y_pred = scaled_rf.predict(X_test_scaled)
#plot_confusion_matrix(df, X_test, y_test)
print(confusion_matrix(y_test_scaled, y_pred))
# Out:
# [[7574 2826]
#  [3105 7495]]

# %%
print(classification_report(y_test_scaled, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.73      0.72     10400
#            1       0.73      0.71      0.72     10600
#
#     accuracy                           0.72     21000
#    macro avg       0.72      0.72      0.72     21000
# weighted avg       0.72      0.72      0.72     21000

# %%
df.columns
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
X_Arthur = [[
    19345, 
    2,
    175,
    85,
    129,
    90,
    2,
    1,
    1,
    0,
    1
]]

print(scaled_rf.predict(X_Arthur))
# Out:
# [1]

# %%
scaled_rf.predict_proba(X_Arthur)
# Out:
# array([[0.36, 0.64]])

# %% [markdown]
# ### Patient is reported with a probability of cancer 64%. Additional examinations could be requested

# %% [markdown]
# * ### Grid Search

# %%
param_grid = {
    'bootstrap': [True, False],
    'max_features': [1, 2],
    'max_depth': [100], #best param
    'min_samples_leaf': [5], #best param
    'min_samples_split': [10], #best param
    'n_estimators': [100, 200] #best param
}

# %%
rf = RandomForestClassifier(random_state=42)
grid = GridSearchCV(estimator = rf, param_grid = param_grid, cv = 5)

# %%
# List parameters
rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'bootstrap': [True, False], 'max_depth': [90],
#                          'max_features': [1, 2], 'min_samples_leaf': [5],
#                          'min_samples_split': [10],
#                          'n_estimators': [100, 200]})

# %%
print("Grid Search Best score:", 100*round(grid.best_score_, 3), "%", "with params:", grid.best_params_)
# Out:
# Grid Search Best score: 73.5 % with params: {'bootstrap': True, 'max_depth': 90, 'max_features': 2, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 200}

# %%
grid.get_params
# Out:
# <bound method BaseEstimator.get_params of GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'bootstrap': [True, False], 'max_depth': [90],
#                          'max_features': [1, 2], 'min_samples_leaf': [5],
#                          'min_samples_split': [10],
#                          'n_estimators': [100, 200]})>

# %%
# Best params GridSearch chosen

grid.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 90,
#  'max_features': 2,
#  'min_samples_leaf': 5,
#  'min_samples_split': 10,
#  'n_estimators': 200}

# %% [markdown]
# ### Best params with non scaled datas are max_depth: 100, max_features: 2, min_samples_leaf: 5, min_samples_split: 10, n_estimators: 200

# %% [markdown]
# #### Comparaison avec d'autres algo

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(max_iter=200, random_state=42).fit(X_train, y_train)
#print('La prediction sur X_test:',clf.predict(X_test))
#print('La prediction_proba sur X_test:',clf.predict_proba(X_test))
print('Logistic Regression Score:',round(100*clf.score(X_train, y_train), 3), "%")
# Out:
# Logistic Regression Score: 69.486 %

# %%
X = [[
    19345, 
    2,
    175,
    85,
    129,
    90,
    2,
    1,
    1,
    0,
    1
]]

print(clf.predict(X))
# Out:
# [0]

# %%
clf.predict_proba(X)
# Out:
# array([[0.54861154, 0.45138846]])

# %% [markdown]
# ## Patient is not reported with a probability of cancer 54%. Additional examinations could be requested

# %% [markdown]
# * ### GradientBoosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1, random_state=42)
gbc.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(learning_rate=1.0, max_depth=1, random_state=42)

# %%
print("GradientBoosting Score:", round(100*clf.score(X_test, y_test), 3), "%")
# Out:
# GradientBoosting Score: 69.762 %

# %% [markdown]
# * ### AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
X = df_cleaned.drop(['cardio'], axis=1)
y = df_cleaned.cardio

clf = AdaBoostClassifier(n_estimators=100)
scores = cross_val_score(clf, X, y, cv=3)
print("AdaBoost, Score:", round(100*scores.mean(), 3), "%")
# Out:
# AdaBoost, Score: 73.069 %

# %% [markdown]
# * ### Neural Network

# %%
from sklearn.neural_network import MLPClassifier

X = df_cleaned.drop(['cardio'], axis=1)
y = df_cleaned.cardio

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

clf = MLPClassifier(random_state=42, max_iter=300).fit(X_train, y_train)
clf.predict_proba(X_test)

clf.predict(X_test)

print("MLP Score:", round(100*clf.score(X_test, y_test), 3), "%")
# Out:
# MLP Score: 69.269 %

# %% [markdown]
# ## In conclusion, we can say with variance reductions of AdaBoost (cross validation = 3 & n_estimators=100) gives the best score in relation to other models (LogReg, GBoost)
